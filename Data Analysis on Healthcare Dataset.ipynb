# %%
import pandas as pd
pd.set_option('display.max_columns',None)
data = pd.read_csv("500_Cities__Local_Data_for_Better_Health__2019_release.csv")
data
# Out:
#         Year StateAbbr      StateDesc           CityName GeographicLevel  \
# 0       2017        GA        Georgia           Savannah    Census Tract
# 1       2017        HI         Hawaii           Honolulu    Census Tract
# 2       2016        GA        Georgia      Sandy Springs            City
# 3       2017        GA        Georgia            Roswell    Census Tract
# 4       2017        HI         Hawaii           Honolulu    Census Tract
# 5       2017        GA        Georgia           Savannah    Census Tract
# 6       2017        IL       Illinois  Arlington Heights    Census Tract
# 7       2017        ID          Idaho         Boise City    Census Tract
# 8       2017        HI         Hawaii           Honolulu    Census Tract
# 9       2016        GA        Georgia           Savannah    Census Tract
# 10      2017        GA        Georgia              Macon    Census Tract
# 11      2016        GA        Georgia            Augusta    Census Tract
# ...

# %%
data.shape
data.describe
# Out:
# <bound method NDFrame.describe of         Year StateAbbr      StateDesc           CityName GeographicLevel  \
# 0       2017        GA        Georgia           Savannah    Census Tract
# 1       2017        HI         Hawaii           Honolulu    Census Tract
# 2       2016        GA        Georgia      Sandy Springs            City
# 3       2017        GA        Georgia            Roswell    Census Tract
# 4       2017        HI         Hawaii           Honolulu    Census Tract
# 5       2017        GA        Georgia           Savannah    Census Tract
# 6       2017        IL       Illinois  Arlington Heights    Census Tract
# 7       2017        ID          Idaho         Boise City    Census Tract
# 8       2017        HI         Hawaii           Honolulu    Census Tract
# 9       2016        GA        Georgia           Savannah    Census Tract
# 10      2017        GA        Georgia              Macon    Census Tract
# ...

# %%
data.CityName.value_counts()
# Out:
# New York          59911
# Los Angeles       28119
# Chicago           22369
# Houston           16787
# Philadelphia      10707
# Phoenix           10097
# San Antonio        9145
# Dallas             8959
# Detroit            8335
# San Diego          8315
# Columbus           8188
# Honolulu           6721
# Kansas City        6529
# San Jose           6185
# Oklahoma City      6155
# Indianapolis       6048
# Milwaukee          6047
# Austin             5770
# Baltimore          5655
# Charlotte          5650
# San Francisco      5515
# Louisville         5176
# Jacksonville       5171
# Portland           5138
# Memphis            5112
# Washington         5065
# Cleveland          4981
# Boston             4971
# New Orleans        4945
# Fort Worth         4746
#                   ...
# Pearland            476
# Turlock             476
# Danbury             476
# Tracy               476
# New Rochelle        476
# Lauderhill          476
# Plymouth            476
# ...

# %%
data.Category.value_counts()
# Out:
# Health Outcomes        376673
# Prevention             288400
# Unhealthy Behaviors    145030
# Name: Category, dtype: int64

# %%
measure = data.Measure.value_counts()
measure.shape
# Out:
# (28,)

# %%
data.Year.value_counts()
# Out:
# 2017    580087
# 2016    230016
# Name: Year, dtype: int64

# %%
state = data.StateAbbr.value_counts()
state.shape
# Out:
# (52,)

# %%
sd = data.StateDesc.value_counts()
sd.shape
# Out:
# (52,)

# %%
cn = data.CityName.value_counts()
cn.shape
# Out:
# (474,)

# %%
data.GeographicLevel.value_counts()
# Out:
# Census Tract    782047
# City             28000
# US                  56
# Name: GeographicLevel, dtype: int64

# %%
data.DataSource.value_counts()
# Out:
# BRFSS    810103
# Name: DataSource, dtype: int64

# %%
data.Category.value_counts()
# Out:
# Health Outcomes        376673
# Prevention             288400
# Unhealthy Behaviors    145030
# Name: Category, dtype: int64

# %%
uid = data.UniqueID.value_counts()
uid.shape
# Out:
# (28505,)

# %%
data.DataValueTypeID.value_counts()
# Out:
# CrdPrv       796075
# AgeAdjPrv     14028
# Name: DataValueTypeID, dtype: int64

# %%
data.Data_Value_Type.value_counts()
# Out:
# Crude prevalence           796075
# Age-adjusted prevalence     14028
# Name: Data_Value_Type, dtype: int64

# %%
dv = data.Data_Value.value_counts()
dv.shape
# Out:
# (946,)

# %%
lcl = data.Low_Confidence_Limit.value_counts()
lcl.shape
# Out:
# (937,)

# %%
hcl = data.High_Confidence_Limit.value_counts()
hcl.shape
# Out:
# (955,)

# %%
pc = data.PopulationCount.value_counts()
pc.shape
# Out:
# (8050,)

# %%
gl = data.GeoLocation.value_counts()
gl.shape
# Out:
# (28504,)

# %%
data.CategoryID.value_counts()
# Out:
# HLTHOUT    376673
# PREVENT    288400
# UNHBEH     145030
# Name: CategoryID, dtype: int64

# %%
mid = data.MeasureId.value_counts()
mid.shape
# Out:
# (28,)

# %%
cfips = data.CityFIPS.value_counts()
cfips.shape
# Out:
# (500,)

# %%
data.CityFIPS.value_counts()
# Out:
# 3651000.0    59911
# 644000.0     28119
# 1714000.0    22369
# 4835000.0    16787
# 4260000.0    10707
# 455000.0     10097
# 4865000.0     9145
# 4819000.0     8959
# 2622000.0     8335
# 666000.0      8315
# 15003.0       6721
# 3918000.0     6648
# 668000.0      6185
# 4055000.0     6155
# 1836003.0     6048
# 5553000.0     6047
# 4805000.0     5770
# 2404000.0     5655
# 3712000.0     5650
# 667000.0      5515
# 2148006.0     5176
# 4748000.0     5112
# 1150000.0     5065
# 3916000.0     4981
# 2507000.0     4971
# 2255000.0     4945
# 4827000.0     4746
# 2938000.0     4719
# 1235000.0     4648
# 4159000.0     4522
#              ...
# 1757225.0      476
# 4856348.0      476
# 680812.0       476
# 1810342.0      476
# 2751730.0      476
# 680238.0       476
# 1239550.0      476
# 3650617.0      476
# 918430.0       476
# 1656260.0      474
# 3456550.0      448
# 5335275.0      448
# 4965330.0      448
# 657792.0       448
# 1342425.0      448
# 4841980.0      446
# ...

# %%
tfips = data.TractFIPS.value_counts()
tfips.shape
# Out:
# (27648,)

# %%
sqt=data.Short_Question_Text.value_counts()
sqt.shape
# Out:
# (28,)

# %%
df = data[['Year','StateAbbr','StateDesc','CityName','GeographicLevel','Category','UniqueID','Measure','PopulationCount','GeoLocation','CategoryID','MeasureId','Short_Question_Text']]
df
# Out:
#         Year StateAbbr      StateDesc           CityName GeographicLevel  \
# 0       2017        GA        Georgia           Savannah    Census Tract
# 1       2017        HI         Hawaii           Honolulu    Census Tract
# 2       2016        GA        Georgia      Sandy Springs            City
# 3       2017        GA        Georgia            Roswell    Census Tract
# 4       2017        HI         Hawaii           Honolulu    Census Tract
# 5       2017        GA        Georgia           Savannah    Census Tract
# 6       2017        IL       Illinois  Arlington Heights    Census Tract
# 7       2017        ID          Idaho         Boise City    Census Tract
# 8       2017        HI         Hawaii           Honolulu    Census Tract
# 9       2016        GA        Georgia           Savannah    Census Tract
# 10      2017        GA        Georgia              Macon    Census Tract
# 11      2016        GA        Georgia            Augusta    Census Tract
# ...

# %%
df.isnull().sum()
# Out:
# Year                    0
# StateAbbr               0
# StateDesc               0
# CityName               56
# GeographicLevel         0
# Category                0
# UniqueID                0
# Measure                 0
# PopulationCount         0
# GeoLocation            56
# CategoryID              0
# MeasureId               0
# Short_Question_Text     0
# dtype: int64

# %%
import numpy as np
df_required = df[df.CityName.notnull()]
df_required
# Out:
#         Year StateAbbr  StateDesc           CityName GeographicLevel  \
# 0       2017        GA    Georgia           Savannah    Census Tract
# 1       2017        HI     Hawaii           Honolulu    Census Tract
# 2       2016        GA    Georgia      Sandy Springs            City
# 3       2017        GA    Georgia            Roswell    Census Tract
# 4       2017        HI     Hawaii           Honolulu    Census Tract
# 5       2017        GA    Georgia           Savannah    Census Tract
# 6       2017        IL   Illinois  Arlington Heights    Census Tract
# 7       2017        ID      Idaho         Boise City    Census Tract
# 8       2017        HI     Hawaii           Honolulu    Census Tract
# 9       2016        GA    Georgia           Savannah    Census Tract
# 10      2017        GA    Georgia              Macon    Census Tract
# 11      2016        GA    Georgia            Augusta    Census Tract
# 12      2016        HI     Hawaii           Honolulu    Census Tract
# ...

# %%
df_required.isnull().sum()
# Out:
# Year                   0
# StateAbbr              0
# StateDesc              0
# CityName               0
# GeographicLevel        0
# Category               0
# UniqueID               0
# Measure                0
# PopulationCount        0
# GeoLocation            0
# CategoryID             0
# MeasureId              0
# Short_Question_Text    0
# dtype: int64

# %%
df_required.Year.dtype
df_required.StateAbbr.dtype
df_required.StateDesc.dtype
df_required.CityName.dtype
df_required.GeographicLevel.dtype
df_required.Category.dtype
df_required.UniqueID.dtype
df_required.Measure.dtype
df_required.PopulationCount.dtype
df_required.GeoLocation.dtype
df_required.CategoryID.dtype
df_required.MeasureId.dtype
df_required.Short_Question_Text.dtype
# Out:
# dtype('int64')
# dtype('O')
# dtype('O')
# dtype('O')
# dtype('O')
# dtype('O')
# dtype('O')
# dtype('O')
# dtype('int64')
# dtype('O')
# dtype('O')
# dtype('O')
# dtype('O')

# %%
df_required.Measure.value_counts()
# Out:
# Cholesterol screening among adults aged >=18 Years                                                                                                                                                29004
# Chronic obstructive pulmonary disease among adults aged >=18 Years                                                                                                                                29004
# Sleeping less than 7 hours among adults aged >=18 Years                                                                                                                                           29004
# Chronic kidney disease among adults aged >=18 Years                                                                                                                                               29004
# ...

# %%
df_required.Category.value_counts()
# Out:
# Health Outcomes        376647
# Prevention             288380
# Unhealthy Behaviors    145020
# Name: Category, dtype: int64

# %%
def measure_short(index):
    measure = df_required[df_required.index == index][['Measure','Category']].values[0]
    if len(measure) > 0:
        print(measure[0])
        print('Category:',measure[1])

# %%
measure_short(3)
# Out:
# Mental health not good for >=14 days among adults aged >=18 Years
# Category: Health Outcomes

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, SpatialDropout1D
from sklearn.model_selection import train_test_split
from keras.utils.np_utils import to_categorical
from keras.callbacks import EarlyStopping
from keras.layers import Dropout
import re
from nltk.corpus import stopwords
from nltk import word_tokenize
STOPWORDS = set(stopwords.words('english'))
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'
# Out:
# Using TensorFlow backend.

# %%
MAX_NB_WORDS = 40
MAX_SEQUENCE_LENGTH = 60
EMBEDDING_DIM = 100

tokenizer = Tokenizer(num_words=MAX_NB_WORDS, filters='!"#$%&()*+,-./:;<=>?@[\]^_`{|}~', lower=True)
tokenizer.fit_on_texts(df_required['Measure'].values)
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 112 unique tokens.

# %%
X = tokenizer.texts_to_sequences(df_required['Measure'].values)
X = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor:', X.shape)
# Out:
# Shape of data tensor: (810047, 60)

# %%
Y = pd.get_dummies(df_required['Category']).values
print('Category:', Y.shape)
# Out:
# Category: (810047, 3)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.10, random_state = 42)
print(X_train.shape,Y_train.shape)
print(X_test.shape,Y_test.shape)
# Out:
# (729042, 60) (729042, 3)
# (81005, 60) (81005, 3)

# %%
model = Sequential()
model.add(Embedding(MAX_NB_WORDS, EMBEDDING_DIM, input_length=X.shape[1]))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(3, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# WARNING:tensorflow:From C:\Users\Suhasini Konimeti\Anaconda3\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_1 (Embedding)      (None, 60, 100)           4000
# _________________________________________________________________
# spatial_dropout1d_1 (Spatial (None, 60, 100)           0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100)               80400
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 303
# ...
# Total params: 84,703
# Trainable params: 84,703
# Non-trainable params: 0
# ...

# %%
epochs = 4
batch_size = 64
history = model.fit(X_train, Y_train, epochs=epochs, batch_size=batch_size ,validation_split=0.1,callbacks=[EarlyStopping(monitor='val_loss', patience=3, min_delta=0.0001)])
# Out:
# WARNING:tensorflow:From C:\Users\Suhasini Konimeti\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 656137 samples, validate on 72905 samples
# Epoch 1/4
# 656137/656137 [==============================] - 709s 1ms/step - loss: 0.2049 - accuracy: 0.8553 - val_loss: 0.1972 - val_accuracy: 0.8578
# Epoch 2/4
# 656137/656137 [==============================] - 701s 1ms/step - loss: 0.2000 - accuracy: 0.8569 - val_loss: 0.1972 - val_accuracy: 0.8578
# Epoch 3/4
# 656137/656137 [==============================] - 743s 1ms/step - loss: 0.1987 - accuracy: 0.8569 - val_loss: 0.1971 - val_accuracy: 0.8578
# Epoch 4/4
# 656137/656137 [==============================] - 702s 1ms/step - loss: 0.1987 - accuracy: 0.8564 - val_loss: 0.1971 - val_accuracy: 0.8578

# %%
new_Measure = ['Current lack of health insurance among adults aged 18–64 Years']
seq = tokenizer.texts_to_sequences(new_Measure)
padded = pad_sequences(seq, maxlen=MAX_SEQUENCE_LENGTH)
pred = model.predict(padded)
labels = ['Health Outcomes','Prevention','Unhealthy Behaviors']
print(pred, labels[np.argmax(pred)])
# Out:
# [[7.9442757e-13 1.0000000e+00 1.3039026e-15]] Prevention

# %%
df_2016 = df_required[['Short_Question_Text']][df_required['Year'] == 2016]
print(df_2016)
# Out:
#                              Short_Question_Text
# 2                                 Pap Smear Test
# 9                                 Pap Smear Test
# 11                                  Dental Visit
# 12                                Pap Smear Test
# 14        Core preventive services for older men
# 17      Core preventive services for older women
# 23                                Sleep <7 hours
# 38                                Pap Smear Test
# 39                   Colorectal Cancer Screening
# 46                                Pap Smear Test
# 48                                   Mammography
# 49                                Sleep <7 hours
# 55                                Pap Smear Test
# 56                                    Teeth Loss
# 60        Core preventive services for older men
# 65                   Colorectal Cancer Screening
# 73                                Pap Smear Test
# 85                                Pap Smear Test
# ...

# %%
SQT_2016 = df_2016.Short_Question_Text.value_counts()
print(SQT_2016)
# Out:
# Dental Visit                                29004
# Sleep <7 hours                              29004
# Pap Smear Test                              28910
# Colorectal Cancer Screening                 28845
# Mammography                                 28725
# Teeth Loss                                  28599
# Core preventive services for older men      28462
# Core preventive services for older women    28451
# Name: Short_Question_Text, dtype: int64

# %%
SQT_2016.plot(kind='bar',color = 'red')
plt.xlabel('ShortQuestionText')
plt.ylabel('Frequency')
plt.title('Frequency Count for ShortQuestionText2016')
plt.show()
# Out:
# Text(0.5, 0, 'ShortQuestionText')
# Text(0, 0.5, 'Frequency')
# Text(0.5, 1.0, 'Frequency Count for ShortQuestionText2016')

# %%
df_2017 = df_required[['Short_Question_Text']][df_required['Year'] == 2017]
print(df_2017)
# Out:
#            Short_Question_Text
# 0               Annual Checkup
# 1       Coronary Heart Disease
# 3                Mental Health
# 4             Health Insurance
# 5              Current Smoking
# 6             Health Insurance
# 7                         COPD
# 8                    Arthritis
# 10       Cholesterol Screening
# 13            High Cholesterol
# 15             Physical Health
# 16               Mental Health
# 18         Physical Inactivity
# 19                        COPD
# 20            Health Insurance
# 22               Mental Health
# 24             Physical Health
# 25                   Arthritis
# 26            Health Insurance
# 27        Taking BP Medication
# 28        Cancer (except skin)
# 29              Binge Drinking
# 30      Chronic Kidney Disease
# 31         Physical Inactivity
# 32             Current Smoking
# 33                        COPD
# 34                        COPD
# 35        Taking BP Medication
# 36             Physical Health
# ...

# %%
SQT_2017 = df_2017.Short_Question_Text.value_counts()
print(SQT_2017)
# Out:
# Arthritis                 29004
# High Cholesterol          29004
# Binge Drinking            29004
# Obesity                   29004
# Diabetes                  29004
# Chronic Kidney Disease    29004
# Physical Health           29004
# Current Asthma            29004
# Mental Health             29004
# High Blood Pressure       29004
# Coronary Heart Disease    29004
# Cancer (except skin)      29004
# Physical Inactivity       29004
# Current Smoking           29004
# Stroke                    29004
# Cholesterol Screening     29004
# COPD                      29004
# Taking BP Medication      29004
# Annual Checkup            29004
# Health Insurance          28971
# Name: Short_Question_Text, dtype: int64

# %%
SQT_2017.plot(kind='bar',color = 'red')
plt.xlabel('ShortQuestionText')
plt.ylabel('Frequency')
plt.title('Frequency Count for ShortQuestionText2017')
plt.show()
# Out:
# Text(0.5, 0, 'ShortQuestionText')
# Text(0, 0.5, 'Frequency')
# Text(0.5, 1.0, 'Frequency Count for ShortQuestionText2017')

# %%
print(SQT_2016.head(5))
# Out:
# Dental Visit                   29004
# Sleep <7 hours                 29004
# Pap Smear Test                 28910
# Colorectal Cancer Screening    28845
# Mammography                    28725
# Name: Short_Question_Text, dtype: int64

# %%
max_2016 = [['DentalVisit',  29004], ['Sleep<7hours',  29004], ['PapSm.Test', 28910],['Col.CancerScr', 28845],['Mammography', 28725]]
plottingdf_2016 = pd.DataFrame(max_2016, columns = ['ShortQuestionText2016', 'count'])
print(plottingdf_2016)
# Out:
#   ShortQuestionText2016  count
# 0           DentalVisit  29004
# 1          Sleep<7hours  29004
# 2            PapSm.Test  28910
# 3         Col.CancerScr  28845
# 4           Mammography  28725

# %%
import matplotlib.pyplot as plt
SQT=plottingdf_2016['ShortQuestionText2016']
frequency=plottingdf_2016['count']
plt.scatter(SQT, frequency, color = 'red')
plt.xlabel('ShortQuestionText2016')
plt.ylabel('count')
plt.title('scatter plot between short question text and count 2016')
plt.show()
# Out:
# Text(0.5, 0, 'ShortQuestionText2016')
# Text(0, 0.5, 'count')
# Text(0.5, 1.0, 'scatter plot between short question text and count 2016')

# %%
print(SQT_2017.head(5))
# Out:
# Arthritis           29004
# High Cholesterol    29004
# Binge Drinking      29004
# Obesity             29004
# Diabetes            29004
# Name: Short_Question_Text, dtype: int64

# %%
max_2017 = [['Arthritis',  29004], ['High Cholesterol',  29004], ['BingeDrinking', 29004],['Obesity', 29004],['Diabetes', 29004]]
plottingdf_2017 = pd.DataFrame(max_2017, columns = ['ShortQuestionText2017', 'count_2017'])
print(plottingdf_2017)
# Out:
#   ShortQuestionText2017  count_2017
# 0             Arthritis       29004
# 1      High Cholesterol       29004
# 2         BingeDrinking       29004
# 3               Obesity       29004
# 4              Diabetes       29004

# %%
SQT=plottingdf_2017['ShortQuestionText2017']
frequency=plottingdf_2017['count_2017']
plt.scatter(SQT, frequency, color = 'red')
plt.xlabel('ShortQuestionText2017')
plt.ylabel('count')
plt.title('scatter plot between short question text and count 2017\n')
plt.show()
#Since the value for the count are equal matplotlib chooses an adaptive scale.
# Out:
# Text(0.5, 0, 'ShortQuestionText2017')
# Text(0, 0.5, 'count')
# Text(0.5, 1.0, 'scatter plot between short question text and count 2017\n')

# %%
print(SQT_2016.head(5), SQT_2017.head(5))
# Out:
# Dental Visit                   29004
# Sleep <7 hours                 29004
# Pap Smear Test                 28910
# Colorectal Cancer Screening    28845
# Mammography                    28725
# Name: Short_Question_Text, dtype: int64 Arthritis           29004
# High Cholesterol    29004
# Binge Drinking      29004
# Obesity             29004
# Diabetes            29004
# Name: Short_Question_Text, dtype: int64
